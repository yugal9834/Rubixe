# %% [markdown]
# # Bussiness Statement:- Predict whether the person has client taken term deposit or not.

# %% [raw]
#    1 - age (numeric)
#    2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
#                                        "blue-collar","self-employed","retired","technician","services")
#    3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#    4 - education (categorical: "unknown","secondary","primary","tertiary")
#    5 - default: has credit in default? (binary: "yes","no")
#    6 - balance: average yearly balance, in euros (numeric)
#    7 - housing: has housing loan? (binary: "yes","no")
#    8 - loan: has personal loan? (binary: "yes","no")
#    # related with the last contact of the current campaign:
#    9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
#   10 - day: last contact day of the month (numeric)
#   11 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#   12 - duration: last contact duration, in seconds (numeric)
#    # other attributes:
#   13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#   14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#   15 - previous: number of contacts performed before this campaign and for this client (numeric)
#   16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
#   Output variable (desired target):
#   17 - y - has the client subscribed a term deposit? (binary: "yes","no")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import sweetviz as sv
import warnings 
warnings.filterwarnings('ignore')

# %%
dfull=pd.read_csv('bank-full.csv',delimiter=';')
dfull.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
dfull_new=pd.read_csv('bank-full.csv',delimiter=';')

# %%
a=dfull.copy()

# %%
dfull.shape
# Out:
# (45211, 17)

# %%
dfull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
dfull.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
dfull.describe(include='O')
# Out:
#                 job  marital  education default housing   loan   contact  \
# count         45211    45211      45211   45211   45211  45211     45211
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9732    27214      23202   44396   25130  37967     29285
#
#         month poutcome      y
# count   45211    45211  45211
# unique     12        4      2
# top       may  unknown     no
# freq    13766    36959  39922

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### univarient Analysis

# %%
plt.figure(figsize=(20,20))
num=1
for c in dfull:
    ax=plt.subplot(6,3,num)
    sb.countplot(dfull[c])
    num+=1
plt.tight_layout()

# %%
report=sv.analyze(dfull)
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Insight from Age
# * the age group between 28 to 32 are present more in number

# %% [markdown]
# # Insight from job
# * the graph has decreasing trend.
# * the blue collar job people are called more.
# * then next management people are called more.

# %% [markdown]
# # Insight form marital
# * the graph has decreasing trend.
# * the married people count is high then other caetorgy
# * the hirarchy of category is married>single>divorced

# %% [markdown]
# # Insight from Education
# * the graph has a decreasing trend.
# * the people having tertiary education is more in number.
# * the hirearchy is tertiary>secondary>primary>unknown.

# %% [markdown]
# # Insight form default
# * 98% people have no credit amount with them.
# * only 2% people have credit with them.

# %% [markdown]
# # Insight from balance
# * no insight

# %% [markdown]
# # Insight form housing
# * 56% peple have taken housing loan and rest did not
# * the people with housing loan might possible not take the term deposit.

# %% [markdown]
# # Insight from loan
# * 84% people did not take any personal loan.
# * it is possible that this 84% people will take term deposit.

# %% [markdown]
# # Insight from contact
# * this has a decresing trend
# * more number of people are contacted through cellular>unknown>telephone.

# %% [markdown]
# # Insight from days
# * no

# %% [markdown]
# # Insight from month
# * the graph has a decresing trend
# * the more people are being contacted in may month then the number is decreasing.
# * may month is crucial month for bank to contact.

# %% [markdown]
# # Insight from duration
# * graph has decreasing trend

# %% [markdown]
# # Insight from campaings
# * graph has decresing trend

# %% [markdown]
# # Insight from pdays
# * maximum people have not being contacted, migth be they did not recieve call.
# * minimun day after which customer is contacted is

# %% [markdown]
# # Insight from previous
# * 81% people have not been contacted early

# %% [markdown]
# # Insight from poutcome
# * the success rate is very much less of people who have been contacted early.
# * the unkown category is present in large count.

# %% [markdown]
# # Insight from y
# * 88% has said no for term deposit
# * 12% has said yes for term deposit

# %% [markdown]
# # Bivarient Analysis

# %%
sb.countplot(dfull.marital, hue=dfull.y)
# Out:
# <AxesSubplot:xlabel='marital', ylabel='count'>

# %%
plt.figure(figsize=(25,25))
numb=1
for c in dfull:
    ax=plt.subplot(6,3,numb)
    sb.countplot(dfull[c],hue=dfull.y)
    numb+=1

# %% [markdown]
# # Sorting dataframe 'a' according to age

# %%
a.sort_values(by='age',ascending=True,axis=0,inplace=True)
a.head()
# Out:
#        age      job marital  education default  balance housing loan  \
# 42954   18  student  single    unknown      no      108      no   no
# 41273   18  student  single    unknown      no        3      no   no
# 42146   18  student  single  secondary      no      156      no   no
# 43637   18  student  single    unknown      no      348      no   no
# 40736   18  student  single    primary      no     1944      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 42954   cellular    9   feb        92         1    183         1  success  yes
# 41273   cellular   25   aug       130         2     -1         0  unknown  yes
# 42146   cellular    4   nov       298         2     82         4    other   no
# 43637   cellular    5   may       443         4     -1         0  unknown  yes
# 40736  telephone   10   aug       122         3     -1         0  unknown   no

# %%
plt.figure(figsize=(20,10))
sb.countplot(x=a.age,hue=a.y)
plt.show()

# %%
plot=sb.countplot(x=a.job,hue=a.y)
plt.setp(plot.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# # Insight from age.
# * every age group has applied for term deposit.
# * the age group betwwen 18 to 32 has increase count in taking term deposit.
# * the count of after age 32 is decreasing.

# %% [markdown]
# # Insight from job
# * the people of job blue-collar,technician, management has more count whoe have taken term deposit.
# * job category unkown housemaid self employed entrepreneur has less count to take term deposit.

# %% [markdown]
# # Insight from marital
# * the graph ahs decresing trend.
# * the hirarchy of term deposit taken is married>single>divorced
# * the bank must focus more on married marital status.

# %% [markdown]
# # Insight from education
# * the approval of term deposit with respect to education is in order secondary>tertiary>primary>unknown.
# * the bank must be focus on secondary and tertiary people more.

# %% [markdown]
# # Insight from default
# * the people having credit with them have not said yes to term deposit.
# * people with no credit with them has applied for term deposit.
# * the people taking credit dependent on there credit.

# %% [markdown]
# # Insigth from balance
# * no trend.

# %% [markdown]
# # Insigth from housing
# * the people who have taken have housing loan have taken term insurance count is less as compared to people having no housing loan

# %% [markdown]
# # Insigth form loan
# * the people count who has not taken any loan count is more to take term deposit.
# * whereas compared to people who have taken loan has very much less count to take term deposit.

# %% [markdown]
# # Insigth from contact
# * the people taking term deposit count is more having contact type cellular.
# * unkown and telephone people taking term deposit is very much less.

# %% [markdown]
# # Insigth from day
# * on an average people taken term deposit and has contacted from 1-30 day have same count.

# %% [markdown]
# # Insigth from month
# * the acceptance of term deposit from may to january has high decresing trend.
# * the acceptance of term deposit in month december and january is very much less.
# * after jan month the acceptance of term deposit is more.

# %% [markdown]
# # Insigth from duration
# * the people who are having long conversation there is a chance of accepting the term deposit.

# %% [markdown]
# # Insigth from campaign
# * the graph has decresing trend with respect to accetance of term deopist and increasing number of contact.
# * the maximun number of contact made to accept term deposit is 8.
# * after 8 contact no one has accepted term deposit.

# %%
plt.hist(a.pdays,bins=8)
plt.show()

# %% [markdown]
# # Insigth from pdays
# * maximum people have not contacted.
# * maximu people have been contacted

# %% [markdown]
# # Insigth from previous
# * maximum number of contact made for a client is 9 days.
# * the client acceptance for term deposit with respect to number of contact made for previous campaing is decreasing.

# %% [markdown]
# # Insigth from poutcome
# * the success rate of previous campaign is very much less.

# %% [markdown]
# # Data Preprocessing

# %%
dfull.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
dfull.shape
# Out:
# (45211, 17)

# %% [markdown]
# # Checking for Nan values

# %%
dfull.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# # Checking for uniques values

# %%
col=dfull.columns
col
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
dfull_temp=dfull.loc[:,['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
       'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
       'previous', 'poutcome', 'y']]

# %%
num=0
for c in dfull_temp:
    print(col[num],'\n',dfull_temp[c].unique())
    num+=1
# Out:
# age
#  [58 44 33 47 35 28 42 43 41 29 53 57 51 45 60 56 32 25 40 39 52 46 36 49
#  59 37 50 54 55 48 24 38 31 30 27 34 23 26 61 22 21 20 66 62 83 75 67 70
#  65 68 64 69 72 71 19 76 85 63 90 82 73 74 78 80 94 79 77 86 95 81 18 89
#  84 87 92 93 88]
# job
#  ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# marital
#  ['married' 'single' 'divorced']
# education
#  ['tertiary' 'secondary' 'unknown' 'primary']
# default
#  ['no' 'yes']
# balance
#  [ 2143    29     2 ...  8205 14204 16353]
# housing
#  ['yes' 'no']
# loan
#  ['no' 'yes']
# contact
#  ['unknown' 'cellular' 'telephone']
# day
#  [ 5  6  7  8  9 12 13 14 15 16 19 20 21 23 26 27 28 29 30  2  3  4 11 17
#  18 24 25  1 10 22 31]
# month
#  ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# duration
#  [ 261  151   76 ... 1298 1246 1556]
# campaign
# ...

# %% [markdown]
# # Label Encoding

# %%
dfull.describe(include='O')
# Out:
#                 job  marital  education default housing   loan   contact  \
# count         45211    45211      45211   45211   45211  45211     45211
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9732    27214      23202   44396   25130  37967     29285
#
#         month poutcome      y
# count   45211    45211  45211
# unique     12        4      2
# top       may  unknown     no
# freq    13766    36959  39922

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for c in dfull:
    if(dfull[c].dtype==object):
        print(dfull[c].unique())
# Out:
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# ['married' 'single' 'divorced']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['no' 'yes']
# ['yes' 'no']
# ['no' 'yes']
# ['unknown' 'cellular' 'telephone']
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# ['unknown' 'failure' 'other' 'success']
# ['no' 'yes']

# %%
for c in dfull.columns:
    if(dfull[c].dtype==object):
        le.fit(dfull[c])
        le.classes_

# %%
for c in dfull.columns:
    if(dfull[c].dtype==object):
        dfull[c]=le.fit_transform(dfull[c])

# %%
le.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
dfull.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8       261         1     -1         0         3  0
# 1    5      8       151         1     -1         0         3  0
# 2    5      8        76         1     -1         0         3  0
# 3    5      8        92         1     -1         0         3  0
# 4    5      8       198         1     -1         0         3  0

# %%
dfull.y.unique()
# Out:
# array([0, 1])

# %%
dfull.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8       261         1     -1         0         3  0
# 1    5      8       151         1     -1         0         3  0
# 2    5      8        76         1     -1         0         3  0
# 3    5      8        92         1     -1         0         3  0
# 4    5      8       198         1     -1         0         3  0

# %%
dfull['duration']=(dfull['duration']/60).round(3)

# %%
dfull.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8     4.350         1     -1         0         3  0
# 1    5      8     2.517         1     -1         0         3  0
# 2    5      8     1.267         1     -1         0         3  0
# 3    5      8     1.533         1     -1         0         3  0
# 4    5      8     3.300         1     -1         0         3  0

# %%
dfull.describe()
# Out:
#                 age           job       marital     education       default  \
# count  45211.000000  45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210      4.339762      1.167725      1.224813      0.018027
# std       10.618762      3.272657      0.608230      0.747997      0.133049
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       33.000000      1.000000      1.000000      1.000000      0.000000
# 50%       39.000000      4.000000      1.000000      1.000000      0.000000
# 75%       48.000000      7.000000      2.000000      2.000000      0.000000
# max       95.000000     11.000000      2.000000      3.000000      1.000000
#
#              balance       housing          loan       contact           day  \
# count   45211.000000  45211.000000  45211.000000  45211.000000  45211.000000
# mean     1362.272058      0.555838      0.160226      0.640242     15.806419
# ...

# %% [markdown]
# # Feature Selection using domain Analysis

# %%
plt.figure(figsize=(20,20))
sb.heatmap(dfull.corr(),annot=True,cmap=plt.cm.afmhot)
# Out:
# <AxesSubplot:>

# %% [markdown]
# * feature poutcomes and pdays are in high correlation with each other so we remove one of them who has less correlation with
#   target variable.
#   i.e poucome has less correlation with target varible so we removw this feature.

# %%
dfull.head(2)
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8     4.350         1     -1         0         3  0
# 1    5      8     2.517         1     -1         0         3  0

# %%
dfull.drop(columns='poutcome',axis=1,inplace=True)
dfull.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  y
# 0    5      8     4.350         1     -1         0  0
# 1    5      8     2.517         1     -1         0  0
# 2    5      8     1.267         1     -1         0  0
# 3    5      8     1.533         1     -1         0  0
# 4    5      8     3.300         1     -1         0  0

# %% [markdown]
# * from domain analysis the features pdays, previous and campaign are not important. so we can remove them

# %%
dfull.drop(columns=['pdays','previous','campaign'],axis=1,inplace=True)
dfull.head(2)
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
#
#    day  month  duration  y
# 0    5      8     4.350  0
# 1    5      8     2.517  0

# %% [markdown]
# # Checking for normally distributed columns

# %%
dist_plot=dfull.loc[:,['balance', 'day', 'duration']]
dist_plot.head()
# Out:
#    balance  day  duration
# 0     2143    5     4.350
# 1       29    5     2.517
# 2        2    5     1.267
# 3     1506    5     1.533
# 4        1    5     3.300

# %%
plt.figure(figsize=(20,20))
numb=1
for c in dist_plot:
    ax=plt.subplot(4,2,numb)
    sb.distplot(dist_plot[c])
    numb+=1

# %%
plt.figure(figsize=(20,20))
numb=1
for c in dist_plot:
    ax=plt.subplot(4,2,numb)
    sb.boxplot(dist_plot[c])
    numb+=1

# %% [markdown]
# # Outlier for Balance
# * since the balance is an important feature its oitlier is important in predicting the target variable.

# %% [markdown]
# # Removing outlier for Duration

# %% [markdown]
# * checking the duration in outlier saying yes to term deposit

# %%
dfull[(dfull['duration']>40) & (dfull['y']==1)].shape
# Out:
# (16, 13)

# %%
dfull[(dfull['duration']>60) & (dfull['y']==1)]
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 9947   59    4        1          1        0     1321        0     0        2
#
#       day  month  duration  y
# 9947    9      6    64.683  1

# %%
dfull[(dfull['duration']>70) & (dfull['y']==0)]
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 24148   59    9        1          2        0     6573        1     0        1
#
#        day  month  duration  y
# 24148   10      9    81.967  0

# %% [markdown]
# * so we can say from above that the some customer who talk for duration in between 40 and 60 minutes
#   have said yes to term deposit so we can not dropo them.
# * the duration greater than 70 min have said no to term deposit so we must remove it its an outlier.

# %%
dfull.iloc[[24148,24149,24150],:]
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 24148   59    9        1          2        0     6573        1     0        1
# 24149   38    4        2          2        0     6490        0     0        1
# 24150   31    4        1          2        0      163        1     1        1
#
#        day  month  duration  y
# 24148   10      9    81.967  0
# 24149   10      9     2.083  0
# 24150   10      9     1.783  0

# %% [markdown]
# * removing index 24148

# %%
dfull.drop(index=24148,axis=0,inplace=True)
dfull.iloc[24148,:]
# Out:
# age            38.000
# job             4.000
# marital         2.000
# education       2.000
# default         0.000
# balance      6490.000
# housing         0.000
# loan            0.000
# contact         1.000
# day            10.000
# month           9.000
# duration        2.083
# y               0.000
# Name: 24149, dtype: float64

# %%
plt.figure(figsize=(20,20))
numb=1
for c in dist_plot:
    ax=plt.subplot(4,2,numb)
    sb.boxplot(dist_plot[c])
    numb+=1

# %% [markdown]
# # Feature scaling

# %%
dfull.describe()
# Out:
#                 age           job       marital     education       default  \
# count  45210.000000  45210.000000  45210.000000  45210.000000  45210.000000
# mean      40.935811      4.339659      1.167728      1.224795      0.018027
# std       10.618540      3.272620      0.608236      0.747997      0.133050
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       33.000000      1.000000      1.000000      1.000000      0.000000
# 50%       39.000000      4.000000      1.000000      1.000000      0.000000
# 75%       48.000000      7.000000      2.000000      2.000000      0.000000
# max       95.000000     11.000000      2.000000      3.000000      1.000000
#
#              balance       housing          loan       contact           day  \
# count   45210.000000  45210.000000  45210.000000  45210.000000  45210.000000
# mean     1362.156802      0.555828      0.160230      0.640234     15.806547
# ...

# %%
dfull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45210 entries, 0 to 45210
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45210 non-null  int64
#  1   job        45210 non-null  int32
#  2   marital    45210 non-null  int32
#  3   education  45210 non-null  int32
#  4   default    45210 non-null  int32
#  5   balance    45210 non-null  int64
#  6   housing    45210 non-null  int32
#  7   loan       45210 non-null  int32
#  8   contact    45210 non-null  int32
#  9   day        45210 non-null  int64
#  10  month      45210 non-null  int32
#  11  duration   45210 non-null  float64
#  12  y          45210 non-null  int32
# dtypes: float64(1), int32(9), int64(3)
# memory usage: 3.3 MB

# %%
from sklearn.preprocessing import scale
a['balance']=scale(a.duration)

# %%
dfull['balance']=scale(dfull['balance']).round(3)

# %%
dfull.describe()
# Out:
#                 age           job       marital     education       default  \
# count  45210.000000  45210.000000  45210.000000  45210.000000  45210.000000
# mean      40.935811      4.339659      1.167728      1.224795      0.018027
# std       10.618540      3.272620      0.608236      0.747997      0.133050
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       33.000000      1.000000      1.000000      1.000000      0.000000
# 50%       39.000000      4.000000      1.000000      1.000000      0.000000
# 75%       48.000000      7.000000      2.000000      2.000000      0.000000
# max       95.000000     11.000000      2.000000      3.000000      1.000000
#
#             balance       housing          loan       contact           day  \
# count  45210.000000  45210.000000  45210.000000  45210.000000  45210.000000
# mean       0.000031      0.555828      0.160230      0.640234     15.806547
# ...

# %%
X=dfull.iloc[:,:-1]
y=dfull.y

# %%
X.head(2)
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0    0.256        1     0        2
# 1   44    9        2          1        0   -0.438        1     0        2
#
#    day  month  duration
# 0    5      8     4.350
# 1    5      8     2.517

# %% [markdown]
# # Feature Selection Using Random Forest
# * Random Forest is one of the embeded Method which does sampling of feature and give the feature which give high Accuracy score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# %%
model=SelectFromModel(RandomForestClassifier(n_estimators=100))
model.fit(X,y)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
model.get_support()
# Out:
# array([ True, False, False, False, False,  True, False, False, False,
#         True,  True,  True])

# %% [markdown]
# ### Final Selected feature to pass to classification Algorithms

# %%
selected_feat=X.columns[(model.get_support())]
len(selected_feat)
# Out:
# 5

# %%
selected_feat
# Out:
# Index(['age', 'balance', 'day', 'month', 'duration'], dtype='object')

# %%
X_new=dfull.loc[:,['age', 'balance', 'day', 'month', 'duration']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_new,y,test_size=0.25,random_state=42)

# %%
from sklearn.metrics import f1_score,accuracy_score, confusion_matrix,classification_report,recall_score

# %% [markdown]
# # Model-1: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model_1=LogisticRegression(max_iter=2500)
model_1.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=2500)

# %%
y_predict=model_1.predict(X_test)

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94      9930
#            1       0.56      0.17      0.26      1373
#
#     accuracy                           0.88     11303
#    macro avg       0.73      0.57      0.60     11303
# weighted avg       0.85      0.88      0.85     11303

# %%
pd.crosstab(y_test,y_predict)
# Out:
# col_0     0    1
# y
# 0      9755  175
# 1      1146  227

# %% [markdown]
# # Model-2: Support Vector Machine

# %%
from sklearn.svm import SVC
model_2=SVC()
model_2.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_predict_2=model_2.predict(X_test)

# %%
accuracy_score(y_test,y_predict_2)
# Out:
# 0.8801203220383969

# %%
recall_score(y_test,y_predict_2)
# Out:
# 0.03860160233066278

# %%
print(classification_report(y_test,y_predict_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9930
#            1       0.60      0.04      0.07      1373
#
#     accuracy                           0.88     11303
#    macro avg       0.74      0.52      0.50     11303
# weighted avg       0.85      0.88      0.83     11303

# %%
pd.crosstab(y_test,y_predict_2)
# Out:
# col_0     0   1
# y
# 0      9895  35
# 1      1320  53

# %% [markdown]
# # Model-3: Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB
model_3=BernoulliNB()
model_3.fit(X_train,y_train)
# Out:
# BernoulliNB()

# %%
y_predict_3=model_3.predict(X_test)

# %%
pd.crosstab(y_test,y_predict_3)
# Out:
# col_0     0
# y
# 0      9930
# 1      1373

# %%
recall_score(y_test,y_predict_3)
# Out:
# 0.0

# %%
print(classification_report(y_test,y_predict_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9930
#            1       0.00      0.00      0.00      1373
#
#     accuracy                           0.88     11303
#    macro avg       0.44      0.50      0.47     11303
# weighted avg       0.77      0.88      0.82     11303

# %% [markdown]
# # Model-4: XgBoost

# %%
from xgboost import XGBClassifier
model_4=XGBClassifier()

# %%
model_4.fit(X_train,y_train)
# Out:
# [18:22:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_predict_4=model_4.predict(X_test)

# %%
accuracy_score(y_test,y_predict_4)
# Out:
# 0.8901176678757852

# %%
pd.crosstab(y_test,y_predict_4)
# Out:
# col_0     0    1
# y
# 0      9544  386
# 1       856  517

# %%
print(classification_report(y_test,y_predict_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      9930
#            1       0.57      0.38      0.45      1373
#
#     accuracy                           0.89     11303
#    macro avg       0.75      0.67      0.70     11303
# weighted avg       0.88      0.89      0.88     11303

# %%
recall_score(y_test,y_predict_4)
# Out:
# 0.37654770575382374

# %% [markdown]
# # Smote

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()
X_train_smote,y_train_smote=smote.fit_resample(X_train,y_train)

# %%
X_train_smote
# Out:
#        age   balance  day  month   duration
# 0       52 -0.409000   25     11   1.750000
# 1       36  0.672000   16      7   6.533000
# 2       36 -0.396000   22      1   2.033000
# 3       37 -0.320000   13      8   6.883000
# 4       39 -0.382000   16      0   2.767000
# ...    ...       ...  ...    ...        ...
# 59977   22 -0.332548   14      3   2.907375
# 59978   55  0.044729   18      1   3.383275
# 59979   61  0.328493   19      8   3.861311
# 59980   58 -0.072019   21      9  11.994051
# 59981   35 -0.356000   14     10   5.498345
#
# [59982 rows x 5 columns]

# %%
X_train_smote.shape
# Out:
# (59982, 5)

# %%
y_train.value_counts()
# Out:
# 0    29991
# 1     3916
# Name: y, dtype: int64

# %%
y_train_smote.value_counts()
# Out:
# 0    29991
# 1    29991
# Name: y, dtype: int64

# %% [markdown]
# # Model-1: Logistic Regression After Smote

# %%
from sklearn.linear_model import LogisticRegression
model_1_s=LogisticRegression(max_iter=2500)

# %%
model_1_s.fit(X_train_smote,y_train_smote)
# Out:
# LogisticRegression(max_iter=2500)

# %%
y_predict_1_s=model_1_s.predict(X_test)

# %%
accuracy_score(y_test,y_predict_1_s)
# Out:
# 0.7870476864549235

# %%
pd.crosstab(y_test,y_predict_1_s)
# Out:
# col_0     0     1
# y
# 0      8018  1912
# 1       495   878

# %%
recall_score(y_test,y_predict_1_s)
# Out:
# 0.6394756008739986

# %%
print(classification_report(y_test,y_predict_1_s))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      9930
#            1       0.31      0.64      0.42      1373
#
#     accuracy                           0.79     11303
#    macro avg       0.63      0.72      0.65     11303
# weighted avg       0.87      0.79      0.82     11303

# %% [markdown]
# # Model-2: Support Vector Machine After smote

# %%
from sklearn.svm import SVC
model_2_s=SVC()
model_2_s.fit(X_train_smote,y_train_smote)
# Out:
# SVC()

# %%
y_predict_2_s=model_2_s.predict(X_test)

# %%
accuracy_score(y_test,y_predict_2_s)
# Out:
# 0.7645757763425639

# %%
pd.crosstab(y_test,y_predict_2_s)
# Out:
# col_0     0     1
# y
# 0      7599  2331
# 1       330  1043

# %%
recall_score(y_test,y_predict_2_s)
# Out:
# 0.7596504005826656

# %%
print(classification_report(y_test,y_predict_2_s))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.77      0.85      9930
#            1       0.31      0.76      0.44      1373
#
#     accuracy                           0.76     11303
#    macro avg       0.63      0.76      0.65     11303
# weighted avg       0.88      0.76      0.80     11303

# %% [markdown]
# # Model-4: XgBoost After Smote

# %%
from xgboost import XGBClassifier
model_4_s=XGBClassifier()

# %%
model_4_s.fit(X_train_smote,y_train_smote)
# Out:
# [18:29:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_predict_4_s=model_4_s.predict(X_test)

# %%
accuracy_score(y_test,y_predict_4_s)
# Out:
# 0.8392462178182784

# %%
pd.crosstab(y_test,y_predict_4_s)
# Out:
# col_0     0     1
# y
# 0      8436  1494
# 1       323  1050

# %%
recall_score(y_test,y_predict_4_s)
# Out:
# 0.764748725418791

# %%
print(classification_report(y_test,y_predict_4_s))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90      9930
#            1       0.41      0.76      0.54      1373
#
#     accuracy                           0.84     11303
#    macro avg       0.69      0.81      0.72     11303
# weighted avg       0.90      0.84      0.86     11303

# %% [markdown]
# # Model-5: Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model_5_s = DecisionTreeClassifier()
model_5_s.fit(X_train_smote,y_train_smote)
# Out:
# DecisionTreeClassifier()

# %%
y_predict_5_s=model_5_s.predict(X_test)

# %%
accuracy_score(y_test,y_predict_5_s)
# Out:
# 0.8137662567459967

# %%
pd.crosstab(y_test,y_predict_5_s)
# Out:
# col_0     0     1
# y
# 0      8407  1523
# 1       582   791

# %%
recall_score(y_test,y_predict_5_s)
# Out:
# 0.5761107064821559

# %%
print(classification_report(y_test,y_predict_5_s))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.85      0.89      9930
#            1       0.34      0.58      0.43      1373
#
#     accuracy                           0.81     11303
#    macro avg       0.64      0.71      0.66     11303
# weighted avg       0.86      0.81      0.83     11303

# %% [markdown]
# # Algorithms Performance
# * Logistic Regression and Xgboost Algorithm perform well after SMOTE with recall Score is .76

# %% [markdown]
# # Hyper parameter Tuning

# %%
# example of grid searching key hyperparametres for logistic regression
from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
#from sklearn.linear_model import LogisticRegression
# define dataset
X_train_smote,y_train_smote= make_blobs(n_samples=1000, centers=2, n_features=5, cluster_std=20)
# define models and parameters
model_h= LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model_h, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train_smote,y_train_smote)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.614333 using {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.610000 (0.056332) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.610000 (0.056332) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.610000 (0.056332) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.610000 (0.056332) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.610000 (0.056332) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.610000 (0.056332) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.610000 (0.056332) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.610000 (0.056332) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.610000 (0.056332) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.610000 (0.056332) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.610000 (0.056332) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# ...

# %%
hyper_model=LogisticRegression(C=0.01, penalty='l2', solver='liblinear')
hyper_model.fit(X_train_smote,y_train_smote)
# Out:
# LogisticRegression(C=0.01, solver='liblinear')

# %%
y_predict_hyper_smote=hyper_model.predict(X_test)

# %%
accuracy_score(y_test,y_predict_hyper_smote)
# Out:
# 0.877643103600814

# %%
pd.crosstab(y_test,y_predict_hyper_smote)
# Out:
# col_0     0    1
# y
# 0      9544  386
# 1       997  376

# %%
print(classification_report(y_test,y_predict_hyper_smote))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93      9930
#            1       0.49      0.27      0.35      1373
#
#     accuracy                           0.88     11303
#    macro avg       0.70      0.62      0.64     11303
# weighted avg       0.86      0.88      0.86     11303

# %% [markdown]
# # The best model is After Smote
# * Support Vector Machine and Xgboost with recall of .76
